# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv('liver_patient.csv')
df.head(5)
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Total_Bilirubin', 'Direct_Bilirubin',
#        'Alkaline_Phosphotase', 'Alamine_Aminotransferase',
#        'Aspartate_Aminotransferase', 'Total_Protiens', 'Albumin',
#        'Albumin_and_Globulin_Ratio', 'Dataset'],
#       dtype='object')

# %%
df.columns.values
# Out:
# array(['Age', 'Gender', 'Total_Bilirubin', 'Direct_Bilirubin',
#        'Alkaline_Phosphotase', 'Alamine_Aminotransferase',
#        'Aspartate_Aminotransferase', 'Total_Protiens', 'Albumin',
#        'Albumin_and_Globulin_Ratio', 'Dataset'], dtype=object)

# %%
df.columns.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of Index(['Age', 'Gender', 'Total_Bilirubin', 'Direct_Bilirubin',
#        'Alkaline_Phosphotase', 'Alamine_Aminotransferase',
#        'Aspartate_Aminotransferase', 'Total_Protiens', 'Albumin',
#        'Albumin_and_Globulin_Ratio', 'Dataset'],
#       dtype='object')>

# %%
df.info
# Out:
# <bound method DataFrame.info of      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65  Female              0.7               0.1                   187
# 1     62    Male             10.9               5.5                   699
# 2     62    Male              7.3               4.1                   490
# 3     58    Male              1.0               0.4                   182
# 4     72    Male              3.9               2.0                   195
# ..   ...     ...              ...               ...                   ...
# 578   60    Male              0.5               0.1                   500
# 579   40    Male              0.6               0.1                    98
# 580   52    Male              0.8               0.2                   245
# 581   31    Male              1.3               0.5                   184
# 582   38    Male              1.0               0.3                   216
#
# ...

# %%
df.describe()
# Out:
#               Age  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# count  583.000000       583.000000        583.000000            583.000000
# mean    44.746141         3.298799          1.486106            290.576329
# std     16.189833         6.209522          2.808498            242.937989
# min      4.000000         0.400000          0.100000             63.000000
# 25%     33.000000         0.800000          0.200000            175.500000
# 50%     45.000000         1.000000          0.300000            208.000000
# 75%     58.000000         2.600000          1.300000            298.000000
# max     90.000000        75.000000         19.700000           2110.000000
#
#        Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# count                583.000000                  583.000000      583.000000
# mean                  80.713551                  109.910806        6.483190
# ...

# %%
df.describe(include='all')
# Out:
#                Age Gender  Total_Bilirubin  Direct_Bilirubin  \
# count   583.000000    583       583.000000        583.000000
# unique         NaN      2              NaN               NaN
# top            NaN   Male              NaN               NaN
# freq           NaN    441              NaN               NaN
# mean     44.746141    NaN         3.298799          1.486106
# std      16.189833    NaN         6.209522          2.808498
# min       4.000000    NaN         0.400000          0.100000
# 25%      33.000000    NaN         0.800000          0.200000
# 50%      45.000000    NaN         1.000000          0.300000
# 75%      58.000000    NaN         2.600000          1.300000
# max      90.000000    NaN        75.000000         19.700000
#
#         Alkaline_Phosphotase  Alamine_Aminotransferase  \
# count             583.000000                583.000000
# unique                   NaN                       NaN
# top                      NaN                       NaN
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Albumin_and_Globulin_Ratio    4
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Dataset                       0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    4
# Dataset                       0
# dtype: int64

# %%
df1=df.dropna()

# %%
df1.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    0
# Dataset                       0
# dtype: int64

# %%
df1["Dataset"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
# sns.set()
# sns.pairplot(df1,hue='Dataset',kind='reg')

# %%
#  correlation 
df1.corr()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_16944\64953268.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.corr()
#                                  Age  Total_Bilirubin  Direct_Bilirubin  \
# Age                         1.000000         0.011000          0.006784
# Total_Bilirubin             0.011000         1.000000          0.874481
# Direct_Bilirubin            0.006784         0.874481          1.000000
# Alkaline_Phosphotase        0.078878         0.205739          0.234008
# Alamine_Aminotransferase   -0.087799         0.213375          0.233180
# Aspartate_Aminotransferase -0.020499         0.237323          0.257022
# Total_Protiens             -0.186248        -0.007906          0.000033
# Albumin                    -0.264211        -0.222087         -0.228409
# ...

# %%
df1.head(3)
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# 1      3.2                        0.74        1
# 2      3.3                        0.89        1

# %%
df=df1

# %%
df.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    0
# Dataset                       0
# dtype: int64

# %%
df['Gender']=df['Gender'].map({'Male':1,'Female':0})
df.head(3)
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_16944\2347319436.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender']=df['Gender'].map({'Male':1,'Female':0})
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65       0              0.7               0.1                   187
# 1   62       1             10.9               5.5                   699
# 2   62       1              7.3               4.1                   490
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# ...

# %%
# create a table for dataset (with and without liver disease) and gender 
df_liver_gender=round(df[["Gender","Dataset"]]
                      .groupby(['Gender'],as_index=False).agg(np.sum),3)

# %%
df_liver_gender
# Out:
#    Gender  Dataset
# 0       0      189
# 1       1      555

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='Gender',y='Dataset',data=df_liver_gender,ci=None)

plt.title("dignosed wrt gender")
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_16944\776158426.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Gender',y='Dataset',data=df_liver_gender,ci=None)
# Text(0.5, 1.0, 'dignosed wrt gender')

# %%
df.groupby(df['Dataset']).count()
# Out:
#          Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# Dataset
# 1        414     414              414               414                   414
# 2        165     165              165               165                   165
#
#          Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# Dataset
# 1                             414                         414             414
# 2                             165                         165             165
#
#          Albumin  Albumin_and_Globulin_Ratio
# Dataset
# 1            414                         414
# 2            165                         165

# %%
#  figure configuration 
fig, axes = plt.subplots(1, 2, figsize=(15, 5))
#  visualize the effect of the datasets (with or without disease ) based on both age and gender .

ld='liver disease'
no_ld=' no liver disease'

# female 
ax=sns.distplot(df[df['Gender']==0]
                [df[df['Gender']==0]['Dataset']==1]['Age'],
                bins=18,label=ld,ax=axes[0],kde=False,color='blue')
ax.legend()
ax=sns.distplot(df[df['Gender']==0]
                [df[df['Gender']==0]['Dataset']==2]['Age'],
                bins=40,label=no_ld,ax=axes[0],kde=False,color='red')
ax.legend()
ax.set_title('Female')
ax.set_ylabel('Counts')

# male
ax=sns.distplot(df[df['Gender']==1]
                [df[df['Gender']==1]['Dataset']==1]['Age'],
                bins=18,label=ld,ax=axes[1],kde=False,color='blue')
ax.legend()
ax=sns.distplot(df[df['Gender']==1]
                [df[df['Gender']==1]['Dataset']==2]['Age'],
                bins=40,label=no_ld,ax=axes[1],kde=False,color='red')
ax.legend()
ax.set_title('Male')
ax.set_ylabel('Counts')
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_16944\1220421927.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sns.distplot(df[df['Gender']==0]
# C:\Users\Acer\AppData\Local\Temp\ipykernel_16944\1220421927.py:13: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
# model

# %%
df.tail()
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 578   60       1              0.5               0.1                   500
# 579   40       1              0.6               0.1                    98
# 580   52       1              0.8               0.2                   245
# 581   31       1              1.3               0.5                   184
# 582   38       1              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 578                        20                          34             5.9
# 579                        35                          31             6.0
# 580                        48                          49             6.4
# 581                        29                          32             6.8
# 582                        21                          24             7.3
#
#      Albumin  Albumin_and_Globulin_Ratio  Dataset
# ...

# %%
X=df.drop(['Dataset'],axis='columns')
y=df['Dataset']

# %%
#  train test split 

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20)

# %%
X_train.head()
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 505   32       1             32.6              14.1                   219
# 16    38       1              1.8               0.8                   342
# 171   44       0              1.9               0.6                   298
# 319   14       1              0.9               0.3                   310
# 217   49       1              1.1               0.5                   159
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 505                        95                         235             5.8
# 16                        168                         441             7.6
# 171                       378                         602             6.6
# 319                        21                          16             8.1
# 217                        30                          31             7.0
#
#      Albumin  Albumin_and_Globulin_Ratio
# ...

# %%
#  standard scaler

from sklearn.preprocessing import StandardScaler
scaler=StandardScaler().fit(X_train)
X_train=scaler.transform(X_train)
X_test=scaler.transform(X_test)

# %%
# X=scaler.transform(X)

# %%
from sklearn.model_selection import ShuffleSplit
cv=ShuffleSplit(n_splits=5,test_size=0.2,random_state=0)

# %%
from sklearn.metrics import confusion_matrix,r2_score
from sklearn.metrics import mean_absolute_error,mean_squared_error
def print_score(test,pred,model):
    Metrics={'Metrics':['accuracy score','f1 score','mean absolute error',
                        'mean squared error','R2 score'],
             'Scores':[accuracy_score(test,pred),f1_score(test,pred),
                       mean_absolute_error(test,pred),mean_squared_error(test,pred),
                       r2_score(test,pred)]}
    df=pd.DataFrame(Metrics)
    return df

# %%
# from sklearn.linear_model import LogisticRegression
# from sklearn.metrics import accuracy_score
# solver=['lbfgs','liblinear','newton-cg','newton-cholesky','sag','saga']
# penalty=[ 'elasticnet', None]
# fit_intercept=['True']
# best_solver=''
# train_score=[]
# train_score=np.zeros(12)
# for i, n in enumerate(solver):
#     for j, m in enumerate(penalty):
#         lr=LogisticRegression(solver=n,penalty=m,max_iter=1000).fit(X_train,y_train)
#         train_score[i]=lr.score(X_test,y_test)
   
#         if lr.score(X_test,y_test)==train_score.max():
#             best_solver=n
#             best_penalty=m


# lr=LogisticRegression(solver=best_solver,penalty=best_penalty,max_iter=1000)
# lr.fit(X_train,y_train)
# lr_pred=lr.predict(X_test)
# print(f'LogisticRegression score: {accuracy_score(y_test,lr_pred)}')

# %%
#  1. logistic regression
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

lr=LogisticRegression()
param_grid=  {
    'penalty' : ['l1', 'l2', 'elasticnet', 'none'],
    'C' : np.logspace(-4, 4, 20),
    'solver' : ['lbfgs','newton-cg','liblinear','sag','saga'],
    'max_iter' : [100, 1000,2500, 5000]
    }

clf=GridSearchCV(lr, param_grid = param_grid, cv = 3, verbose=True, n_jobs=-1)
lr_clf=clf.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 1600 candidates, totalling 4800 fits
# c:\ProgramData\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 2160 fits failed out of a total of 4800.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 240 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
# ...

# %%
print(lr_clf.best_estimator_)
print(lr_clf.best_params_)
lr_pred=lr_clf.predict(X_test)
# Out:
# LogisticRegression(C=0.23357214690901212, penalty='l1', solver='saga')
# {'C': 0.23357214690901212, 'max_iter': 100, 'penalty': 'l1', 'solver': 'saga'}

# %%
#  evaluating Logistic Regression model
print_score(y_test,lr_pred,'Logistic Regression')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\5th sem\machine learning\ml clz\liver_disease\liver_disease_model.ipynb Cell 39 line 2
#       <a href='vscode-notebook-cell:/d%3A/5th%20sem/machine%20learning/ml%20clz/liver_disease/liver_disease_model.ipynb#X53sZmlsZQ%3D%3D?line=0'>1</a> #  evaluating Logistic Regression model
# ----> <a href='vscode-notebook-cell:/d%3A/5th%20sem/machine%20learning/ml%20clz/liver_disease/liver_disease_model.ipynb#X53sZmlsZQ%3D%3D?line=1'>2</a> print_score(y_test,lr_pred,'Logistic Regression')
#
# d:\5th sem\machine learning\ml clz\liver_disease\liver_disease_model.ipynb Cell 39 line 6
#       <a href='vscode-notebook-cell:/d%3A/5th%20sem/machine%20learning/ml%20clz/liver_disease/liver_disease_model.ipynb#X53sZmlsZQ%3D%3D?line=2'>3</a> def print_score(test,pred,model):
# ...

# %%
#2. support vector machine (svm)

from sklearn.svm import SVC
kernels={'linear':0,'poly':0,'rbf':0,'sigmoid':0}
best=''
for i in kernels:
    svm=SVC(kernel=i)
    svm.fit(X_train,y_train)
    yhat=svm.predict(X_test)
    kernels[i]=f1_score(y_test,yhat,average='weighted')
    if kernels[i]==max(kernels.values()):
        best=i
    svm=SVC(kernel=best)
    svm.fit(X_train,y_train)
    svm_pred=svm.predict(X_test)
print(f'svm sccuracy score kernel({best}):{accuracy_score(y_test,svm_pred)}')
# Out:
# svm sccuracy score kernel(sigmoid):0.7241379310344828

# %%
# evaluating svm moodel
print_score(y_test,svm_pred,'SNM')
# Out:
#                Metrics    Scores
# 0       accuracy score  0.724138
# 1             f1 score  0.835052
# 2  mean absolute error  0.275862
# 3   mean squared error  0.275862
# 4             R2 score -0.408729

# %%
# 3. decision tree classifier 
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

dtree=DecisionTreeClassifier(class_weight='balanced')
params={
    'criterion':['gini', 'entropy', 'log_loss'],
    'splitter':['best','random'],
    'max_depth':[3,4,5,6,7,8],
    'min_samples_split':[2,3,4],
    'random_state':[0,25,42,50],
    'max_features': ['auto', 'sqrt', 'log2'],
    
}

clf=GridSearchCV(dtree,params,cv=3,n_jobs=-1)
dtree_clf=clf.fit(X_train,y_train)

dtc_pred=dtree_clf.predict(X_test)

print(best_dtree.best_estimator_)
print(best_dtree.best_params_)
# Out:
# DecisionTreeClassifier(class_weight='balanced', max_depth=8, random_state=42)
# {'max_depth': 8, 'min_samples_split': 2, 'random_state': 42}
# c:\ProgramData\anaconda3\lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(

# %%
# evaluating decision tree
print_score(y_test,dtc_pred,'DecisionTreeClassifier')
# Out:
#                Metrics    Scores
# 0       accuracy score  0.612069
# 1             f1 score  0.701987
# 2  mean absolute error  0.387931
# 3   mean squared error  0.387931
# 4             R2 score -0.981025

# %%
#4. knn 

from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
params={
    'n_neighbors':[5,6,7,8,9,10],
    'leaf_size':[1,2,3,5],
    'weights':['uniform','distance'],
    'algorithm':['auto','ball_tree','kd_tree','brute'],
    'n_jobs':[-1],
    
}
clf=GridSearchCV(knn,params,cv=4)
knn_clf=clf.fit(X_train,y_train)
knn_pred=knn_clf.predict(X_test)

# %%
print("best parameter:",knn_clf.best_params_)


from sklearn.metrics import confusion_matrix
print("confussion matrix:\n",confusion_matrix(y_pred,y_test))
# Out:
# best parameter: {'algorithm': 'auto', 'leaf_size': 1, 'n_jobs': -1, 'n_neighbors': 6, 'weights': 'uniform'}
# confussion matrix:
#  [[72 24]
#  [13  7]]

# %%
print_score(y_test,knn_pred,'KNeighborsClassifier')
# Out:
#                Metrics    Scores
# 0       accuracy score  0.681034
# 1             f1 score  0.795580
# 2  mean absolute error  0.318966
# 3   mean squared error  0.318966
# 4             R2 score -0.628843

# %%
# 5. random forest 

from sklearn.ensemble import RandomForestClassifier

rfc=RandomForestClassifier()
params={
    'criterion':['gini','entropy','logloss'],
    'n_estimators':[10,15,20,25,30],
    'min_samples_leaf':[1,2,3],
    'min_samples_split':[3,4,5,6,7], 
    'random_state':[123],
    'n_jobs':[-1],
    'max_features': ['sqrt', 'log2', None],
    'max_leaf_nodes': [3, 6, 9]
}
clf=GridSearchCV(rfc,params,cv=cv)
rfc_clf=clf.fit(X_train,y_train)
# Out:
# c:\ProgramData\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 3375 fits failed out of a total of 10125.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 3375 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\ProgramData\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 340, in fit
#     self._validate_params()
#   File "c:\ProgramData\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_params
#     validate_parameter_constraints(
# ...

# %%
rfc_pred=rfc_clf.predict(X_test)
print("best rf parameter:",rfc_clf.best_params_)
print_score(y_test,rfc_pred,RandomForestClassifier)
# Out:
# best rf parameter: {'criterion': 'entropy', 'max_features': 'sqrt', 'max_leaf_nodes': 6, 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 20, 'n_jobs': -1, 'random_state': 123}
#                Metrics    Scores
# 0       accuracy score  0.732759
# 1             f1 score  0.835979
# 2  mean absolute error  0.267241
# 3   mean squared error  0.267241
# 4             R2 score -0.364706

# %%
#  adaboost , naive baise ,
